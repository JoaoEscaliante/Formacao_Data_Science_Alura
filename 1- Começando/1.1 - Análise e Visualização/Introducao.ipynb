# %% [markdown]
# #Inicio

# %%
import pandas as pd

pd.read_csv("ratings.csv")
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
import pandas as pd

notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas['nota'].mean()
# Out:
# 3.501556983616962

# %%
notas['nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
notas.nota.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas['nota'].unique()
notas['nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
 print("Media",notas.nota.mean())
 print("Mediana",notas.nota.median())
# Out:
# Media 3.501556983616962
# Mediana 3.5

# %% [markdown]
# # Olhando os filmes part 2

# %%
#import pandas as pd

#pd.read_csv("movies.csv")

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = [ "filmeID", "titulo", "generos"]
filmes.head()
# Out:
#    filmeID                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %% [markdown]
# # 2.1 - Analisando algumas notas especificas por filme

# %%
notas.query("filmeId==1")
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# ...          ...      ...   ...         ...
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
notas.query("filmeId==2").nota.mean()
# Out:
# 3.4318181818181817

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
medias_por_filme = notas.groupby("filmeId").mean().nota
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# '

# %%
import seaborn as sns
sns.boxplot(medias_por_filme)
# Out:
# <Axes: ylabel='nota'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
sns.distplot(medias_por_filme)
# Out:
# <ipython-input-20-c99e5fbcf4e4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(medias_por_filme)
# <Axes: xlabel='nota', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
plt.hist(medias_por_filme)

plt.title("Histograma das médias dos filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos filmes')

# %% [markdown]
# # 2.2 - Boxplot

# %%
notas.nota.plot(kind='hist')
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas.nota)
# Out:
# <Axes: ylabel='nota'>

# %% [markdown]
# # O3. Outro arquivo

# %%
tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.original_language.unique() #categorica nominal
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
# categorica ordinal
# primeiro grau
# segundo grau
# terceiro grau
# primeiro grau  < segundo grau < tercerio grau
#---------------------------------------------------
# budget -> orçamento -> qunatitativo continuo
#---------------------------------------------------
# quantidade de votos -> 1, 2, 3, 4 não têm 2,5 votos.
# notas do movielens -> 0.5, 1, 1.5 ..., 5 não tem 2.7

# %%
tmdb.vote_average.unique()
# Out:
# array([ 7.2,  6.9,  6.3,  7.6,  6.1,  5.9,  7.4,  7.3,  5.7,  5.4,  7. ,
#         6.5,  6.4,  6.2,  7.1,  5.8,  6.6,  7.5,  5.5,  6.7,  6.8,  6. ,
#         5.1,  7.8,  5.6,  5.2,  8.2,  7.7,  5.3,  8. ,  4.8,  4.9,  7.9,
#         8.1,  4.7,  5. ,  4.2,  4.4,  4.1,  3.7,  3.6,  3. ,  3.9,  4.3,
#         4.5,  3.4,  4.6,  8.3,  3.5,  4. ,  2.3,  3.2,  0. ,  3.8,  2.9,
#         8.5,  1.9,  3.1,  3.3,  2.2,  0.5,  9.3,  8.4,  2.7, 10. ,  1. ,
#         2. ,  2.8,  9.5,  2.6,  2.4])

# %% [markdown]
# # O4. Visualização data

# %%
tmdb.vote_average.unique()
# Out:
# array([ 7.2,  6.9,  6.3,  7.6,  6.1,  5.9,  7.4,  7.3,  5.7,  5.4,  7. ,
#         6.5,  6.4,  6.2,  7.1,  5.8,  6.6,  7.5,  5.5,  6.7,  6.8,  6. ,
#         5.1,  7.8,  5.6,  5.2,  8.2,  7.7,  5.3,  8. ,  4.8,  4.9,  7.9,
#         8.1,  4.7,  5. ,  4.2,  4.4,  4.1,  3.7,  3.6,  3. ,  3.9,  4.3,
#         4.5,  3.4,  4.6,  8.3,  3.5,  4. ,  2.3,  3.2,  0. ,  3.8,  2.9,
#         8.5,  1.9,  3.1,  3.3,  2.2,  0.5,  9.3,  8.4,  2.7, 10. ,  1. ,
#         2. ,  2.8,  9.5,  2.6,  2.4])

# %%
contagem_de_lingua = tmdb["original_language"].value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ["original_language", "total"]
contagem_de_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
sns.barplot(x="original_language", y= "total", data= contagem_de_lingua)
# Out:
# <Axes: xlabel='original_language', ylabel='total'>

# %%
sns.catplot(x="original_language", kind="count", data = tmdb)

# %%
plt.pie(contagem_de_lingua["total"], labels = contagem_de_lingua["original_language"])
# Out:
# ([<matplotlib.patches.Wedge at 0x78ce7e03a350>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'zh'),
#   Text(1.0773191105706255, -0.22222406260195313, 'de'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ru'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ko'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'nl'),
#   Text(1.0990363161210686, -0.04603450713357274, 'fa'),
# ...

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc["en"]
total_do_resto = total_geral - total_de_ingles
print(total_de_ingles, total_do_resto)
# Out:
# 4505 298

# %%
dados = {
    'lingua' : ['ingles', 'outros'],
    'total' : [total_de_ingles, total_do_resto]
}
dados = pd.DataFrame(dados)
sns.barplot(x="lingua", y="total", data = dados)
# Out:
# <Axes: xlabel='lingua', ylabel='total'>

# %%
plt.pie(dados["total"], labels = dados["lingua"])
# Out:
# ([<matplotlib.patches.Wedge at 0x78ce7dd95120>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'ingles'),
#   Text(1.0791697511565306, -0.2130555049482467, 'outros')])

# %%
total_por_lingua_de_outros_filmes = tmdb.query("original_language != 'en'").original_language.value_counts()
total_por_lingua_de_outros_filmes
# Out:
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# ja    16
# it    14
# cn    12
# ko    11
# ru    11
# pt     9
# da     7
# sv     5
# fa     4
# nl     4
# he     3
# th     3
# ro     2
# id     2
# ar     2
# cs     2
# ta     2
# tr     1
# nb     1
# af     1
# pl     1
# is     1
# hu     1
# vi     1
# ky     1
# xx     1
# te     1
# no     1
# sl     1
# ps     1
# el     1
# Name: original_language, dtype: int64

# %% [markdown]
# # O5. Continuação da Visualização data

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query("original_language != 'en'")

plt.figure(figsize=(5,10))
sns.catplot(x="original_language", kind="count", data = filmes_sem_lingua_original_em_ingles)

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query("original_language != 'en'")

plt.figure(figsize=(5,10))
sns.catplot(x="original_language", kind="count", data = filmes_sem_lingua_original_em_ingles, aspect = 2,
            order = total_por_lingua_de_outros_filmes.index,
            palette="GnBu_d")
# Out:
# <ipython-input-43-3ce4f1387c14>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="original_language", kind="count", data = filmes_sem_lingua_original_em_ingles, aspect = 2,

# %% [markdown]
# # O6. Média/mediana/desvio padrão/boxplot/histograma

# %%
filmes.head(2)
# Out:
#    filmeID            titulo                                      generos
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
notas_do_toy_story = notas.query("filmeId==1")
notas_do_jumanji = notas.query("filmeId==2")
print(len(notas_do_toy_story), len(notas_do_jumanji))
# Out:
# 215 110

# %%
print("Nota média do Toy Story  %.2f" % notas_do_toy_story.nota.mean())
print("Nota média do Jumanji  %.2f" % notas_do_jumanji.nota.mean())
# Out:
# Nota média do Toy Story  3.92
# Nota média do Jumanji  3.43

# %%
print("Nota média do Toy Story  %.2f" % notas_do_toy_story.nota.median())
print("Nota média do Jumanji  %.2f" % notas_do_jumanji.nota.median())
# Out:
# Nota média do Toy Story  4.00
# Nota média do Jumanji  3.50

# %%
import numpy as np
filme1 = np.append(([2.5]) * 10, np.array([3.5]) * 10)
filme2 = np.append(([5]) * 10, np.array([1]) * 10)

# %%
print(filme1.mean(), filme2.mean())
# Out:
# 5.454545454545454 5.454545454545454

# %%
sns.distplot(filme1)
sns.distplot(filme2)
# Out:
# <ipython-input-60-581cbd9a359d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(filme1)
# <ipython-input-60-581cbd9a359d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(filme2)
# <Axes: ylabel='Density'>

# %%
plt.boxplot([notas_do_toy_story.nota, notas_do_jumanji.nota])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78ce7c38e710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78ce7ca33ca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78ce7c38d150>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x78ce7c475f60>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x78ce7c477ee0>,
# ...
#  'means': []}

# %%
sns.boxplot(x= "filmeId", y = "nota", data = notas.query("filmeId in [1,2,3,4,5]"))
# Out:
# <Axes: xlabel='filmeId', ylabel='nota'>

# %% [markdown]
# # 6.1. Conclusao
